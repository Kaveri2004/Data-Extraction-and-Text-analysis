# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import re
from textblob import TextBlob
import syllapy

# %%
# Step 1: Extracting Article Texts
def extract_article_text(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Assuming the title is in a <title> tag and the article in <article> or similar tag
    title = soup.find('title').get_text()
    article = soup.find('article')
    if not article:
        article = soup.find(attrs={"class": "article-content"})  # Example class, change as per actual site structure
    
    paragraphs = article.find_all('p')
    article_text = '\n'.join([p.get_text() for p in paragraphs])
    
    return title, article_text

# %%
# Read the input Excel file
input_df = pd.read_excel('Input.xlsx')

# %%
# Create directory for articles if not exists
os.makedirs('articles', exist_ok=True)

# %%
# Extract and save articles
for index, row in input_df.iterrows():
    url_id = row['URL_ID']
    url = row['URL']
    try:
        title, text = extract_article_text(url)
        with open(f'articles/{url_id}.txt', 'w', encoding='utf-8') as file:
            file.write(title + "\n\n" + text)
        print(f"Article {url_id} extracted successfully.")
    except Exception as e:
        print(f"Failed to extract article {url_id}: {e}")
# Out:
# Article blackassign0001 extracted successfully.
# Article blackassign0002 extracted successfully.
# Article blackassign0003 extracted successfully.
# Article blackassign0004 extracted successfully.
# Article blackassign0005 extracted successfully.
# Article blackassign0006 extracted successfully.
# Article blackassign0007 extracted successfully.
# Article blackassign0008 extracted successfully.
# Article blackassign0009 extracted successfully.
# Article blackassign0010 extracted successfully.
# Article blackassign0011 extracted successfully.
# Article blackassign0012 extracted successfully.
# Article blackassign0013 extracted successfully.
# Article blackassign0014 extracted successfully.
# Article blackassign0015 extracted successfully.
# Article blackassign0016 extracted successfully.
# Article blackassign0017 extracted successfully.
# Article blackassign0018 extracted successfully.
# Article blackassign0019 extracted successfully.
# Article blackassign0020 extracted successfully.
# Article blackassign0021 extracted successfully.
# Article blackassign0022 extracted successfully.
# Article blackassign0023 extracted successfully.
# Article blackassign0024 extracted successfully.
# Article blackassign0025 extracted successfully.
# Article blackassign0026 extracted successfully.
# Article blackassign0027 extracted successfully.
# Article blackassign0028 extracted successfully.
# Article blackassign0029 extracted successfully.
# Article blackassign0030 extracted successfully.
# Article blackassign0031 extracted successfully.
# Article blackassign0032 extracted successfully.
# Article blackassign0033 extracted successfully.
# Article blackassign0034 extracted successfully.
# Article blackassign0035 extracted successfully.
# Failed to extract article blackassign0036: 'NoneType' object has no attribute 'find_all'
# Article blackassign0037 extracted successfully.
# Article blackassign0038 extracted successfully.
# Article blackassign0039 extracted successfully.
# Article blackassign0040 extracted successfully.
# Article blackassign0041 extracted successfully.
# Article blackassign0042 extracted successfully.
# Article blackassign0043 extracted successfully.
# Article blackassign0044 extracted successfully.
# Article blackassign0045 extracted successfully.
# Article blackassign0046 extracted successfully.
# Article blackassign0047 extracted successfully.
# Article blackassign0048 extracted successfully.
# Failed to extract article blackassign0049: 'NoneType' object has no attribute 'find_all'
# Article blackassign0050 extracted successfully.
# Article blackassign0051 extracted successfully.
# Article blackassign0052 extracted successfully.
# Article blackassign0053 extracted successfully.
# Article blackassign0054 extracted successfully.
# Article blackassign0055 extracted successfully.
# Article blackassign0056 extracted successfully.
# Article blackassign0057 extracted successfully.
# Article blackassign0058 extracted successfully.
# Article blackassign0059 extracted successfully.
# Article blackassign0060 extracted successfully.
# Article blackassign0061 extracted successfully.
# Article blackassign0062 extracted successfully.
# Article blackassign0063 extracted successfully.
# Article blackassign0064 extracted successfully.
# Article blackassign0065 extracted successfully.
# Article blackassign0066 extracted successfully.
# Article blackassign0067 extracted successfully.
# Article blackassign0068 extracted successfully.
# Article blackassign0069 extracted successfully.
# Article blackassign0070 extracted successfully.
# Article blackassign0071 extracted successfully.
# Article blackassign0072 extracted successfully.
# Article blackassign0073 extracted successfully.
# Article blackassign0074 extracted successfully.
# Article blackassign0075 extracted successfully.
# Article blackassign0076 extracted successfully.
# Article blackassign0077 extracted successfully.
# Article blackassign0078 extracted successfully.
# Article blackassign0079 extracted successfully.
# Article blackassign0080 extracted successfully.
# Article blackassign0081 extracted successfully.
# Article blackassign0082 extracted successfully.
# Article blackassign0083 extracted successfully.
# Article blackassign0084 extracted successfully.
# Article blackassign0085 extracted successfully.
# Article blackassign0086 extracted successfully.
# Article blackassign0087 extracted successfully.
# Article blackassign0088 extracted successfully.
# Article blackassign0089 extracted successfully.
# Article blackassign0090 extracted successfully.
# Article blackassign0091 extracted successfully.
# Article blackassign0092 extracted successfully.
# Article blackassign0093 extracted successfully.
# Article blackassign0094 extracted successfully.
# Article blackassign0095 extracted successfully.
# Article blackassign0096 extracted successfully.
# Article blackassign0097 extracted successfully.
# Article blackassign0098 extracted successfully.
# Article blackassign0099 extracted successfully.
# Article blackassign0100 extracted successfully.

# %%
# Step 2: Performing Text Analysis
# Load positive and negative words
with open('positive-words.txt', 'r', encoding='utf-8') as file:
    positive_words = set(file.read().split())
with open('negative-words.txt', 'r', encoding='utf-8', errors='ignore') as file:
    negative_words = set(file.read().split())

# %%
def analyze_text(text):
    blob = TextBlob(text)
    sentences = blob.sentences
    words = blob.words
    
    word_count = len(words)
    sentence_count = len(sentences)
    
    positive_score = sum(1 for word in words if word.lower() in positive_words)
    negative_score = sum(1 for word in words if word.lower() in negative_words)
    
    polarity_score = (positive_score - negative_score) / ((positive_score + negative_score) + 0.000001)
    subjectivity_score = blob.sentiment.subjectivity
    
    avg_sentence_length = word_count / sentence_count
    
    complex_words = [word for word in words if syllapy.count(word) > 2]
    complex_word_count = len(complex_words)
    percentage_complex_words = complex_word_count / word_count
    
    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)
    
    syllables_per_word = sum(syllapy.count(word) for word in words) / word_count
    
    personal_pronouns = len(re.findall(r'\b(I|we|my|ours|us)\b', text, re.I))
    
    avg_word_length = sum(len(word) for word in words) / word_count
    
    return {
        "POSITIVE SCORE": positive_score,
        "NEGATIVE SCORE": negative_score,
        "POLARITY SCORE": polarity_score,
        "SUBJECTIVITY SCORE": subjectivity_score,
        "AVG SENTENCE LENGTH": avg_sentence_length,
        "PERCENTAGE OF COMPLEX WORDS": percentage_complex_words,
        "FOG INDEX": fog_index,
        "AVG NUMBER OF WORDS PER SENTENCE": avg_sentence_length,
        "COMPLEX WORD COUNT": complex_word_count,
        "WORD COUNT": word_count,
        "SYLLABLE PER WORD": syllables_per_word,
        "PERSONAL PRONOUNS": personal_pronouns,
        "AVG WORD LENGTH": avg_word_length
    }

# %%
# Step 3: Saving the Results
# Read the input and output structure files
input_df = pd.read_excel('Input.xlsx')
output_structure = pd.read_excel('Output Data Structure.xlsx')

# %%
# Initialize the output DataFrame
output_df = pd.DataFrame(columns=output_structure.columns)

# %%
# Analyze each extracted article and append results to the output DataFrame
results = []  # To store each row of the results

# %%
for index, row in input_df.iterrows():
    url_id = row['URL_ID']
    try:
        with open(f'articles/{url_id}.txt', 'r', encoding='utf-8') as file:
            text = file.read()
            analysis_results = analyze_text(text)
            analysis_results.update(row.to_dict())
            results.append(analysis_results)
            print(f"Analysis for article {url_id} completed.")
    except Exception as e:
        print(f"Failed to analyze article {url_id}: {e}")
# Out:
# Analysis for article blackassign0001 completed.
# Analysis for article blackassign0002 completed.
# Analysis for article blackassign0003 completed.
# Analysis for article blackassign0004 completed.
# Analysis for article blackassign0005 completed.
# Analysis for article blackassign0006 completed.
# Analysis for article blackassign0007 completed.
# Analysis for article blackassign0008 completed.
# Analysis for article blackassign0009 completed.
# Analysis for article blackassign0010 completed.
# Analysis for article blackassign0011 completed.
# Analysis for article blackassign0012 completed.
# Analysis for article blackassign0013 completed.
# Analysis for article blackassign0014 completed.
# Analysis for article blackassign0015 completed.
# Analysis for article blackassign0016 completed.
# Analysis for article blackassign0017 completed.
# Analysis for article blackassign0018 completed.
# Analysis for article blackassign0019 completed.
# Analysis for article blackassign0020 completed.
# Analysis for article blackassign0021 completed.
# Analysis for article blackassign0022 completed.
# Analysis for article blackassign0023 completed.
# Analysis for article blackassign0024 completed.
# Analysis for article blackassign0025 completed.
# Analysis for article blackassign0026 completed.
# Analysis for article blackassign0027 completed.
# Analysis for article blackassign0028 completed.
# Analysis for article blackassign0029 completed.
# Analysis for article blackassign0030 completed.
# Analysis for article blackassign0031 completed.
# Analysis for article blackassign0032 completed.
# Analysis for article blackassign0033 completed.
# Analysis for article blackassign0034 completed.
# Analysis for article blackassign0035 completed.
# Failed to analyze article blackassign0036: [Errno 2] No such file or directory: 'articles/blackassign0036.txt'
# Analysis for article blackassign0037 completed.
# Analysis for article blackassign0038 completed.
# Analysis for article blackassign0039 completed.
# Analysis for article blackassign0040 completed.
# Analysis for article blackassign0041 completed.
# Analysis for article blackassign0042 completed.
# Analysis for article blackassign0043 completed.
# Analysis for article blackassign0044 completed.
# Analysis for article blackassign0045 completed.
# Analysis for article blackassign0046 completed.
# Analysis for article blackassign0047 completed.
# Analysis for article blackassign0048 completed.
# Failed to analyze article blackassign0049: [Errno 2] No such file or directory: 'articles/blackassign0049.txt'
# Analysis for article blackassign0050 completed.
# Analysis for article blackassign0051 completed.
# Analysis for article blackassign0052 completed.
# Analysis for article blackassign0053 completed.
# Analysis for article blackassign0054 completed.
# Analysis for article blackassign0055 completed.
# Analysis for article blackassign0056 completed.
# Analysis for article blackassign0057 completed.
# Analysis for article blackassign0058 completed.
# Analysis for article blackassign0059 completed.
# Analysis for article blackassign0060 completed.
# Analysis for article blackassign0061 completed.
# Analysis for article blackassign0062 completed.
# Analysis for article blackassign0063 completed.
# Analysis for article blackassign0064 completed.
# Analysis for article blackassign0065 completed.
# Analysis for article blackassign0066 completed.
# Analysis for article blackassign0067 completed.
# Analysis for article blackassign0068 completed.
# Analysis for article blackassign0069 completed.
# Analysis for article blackassign0070 completed.
# Analysis for article blackassign0071 completed.
# Analysis for article blackassign0072 completed.
# Analysis for article blackassign0073 completed.
# Analysis for article blackassign0074 completed.
# Analysis for article blackassign0075 completed.
# Analysis for article blackassign0076 completed.
# Analysis for article blackassign0077 completed.
# Analysis for article blackassign0078 completed.
# Analysis for article blackassign0079 completed.
# Analysis for article blackassign0080 completed.
# Analysis for article blackassign0081 completed.
# Analysis for article blackassign0082 completed.
# Analysis for article blackassign0083 completed.
# Analysis for article blackassign0084 completed.
# Analysis for article blackassign0085 completed.
# Analysis for article blackassign0086 completed.
# Analysis for article blackassign0087 completed.
# Analysis for article blackassign0088 completed.
# Analysis for article blackassign0089 completed.
# Analysis for article blackassign0090 completed.
# Analysis for article blackassign0091 completed.
# Analysis for article blackassign0092 completed.
# Analysis for article blackassign0093 completed.
# Analysis for article blackassign0094 completed.
# Analysis for article blackassign0095 completed.
# Analysis for article blackassign0096 completed.
# Analysis for article blackassign0097 completed.
# Analysis for article blackassign0098 completed.
# Analysis for article blackassign0099 completed.
# Analysis for article blackassign0100 completed.

# %%
# Create a DataFrame from the results list
output_df = pd.DataFrame(results, columns=output_structure.columns)

# %%
# Ensure there are no issues with data
print(output_df.head(50))
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# 5   blackassign0006  https://insights.blackcoffer.com/the-rise-of-t...
# 6   blackassign0007  https://insights.blackcoffer.com/rise-of-cyber...
# 7   blackassign0008  https://insights.blackcoffer.com/rise-of-inter...
# 8   blackassign0009  https://insights.blackcoffer.com/rise-of-cyber...
# 9   blackassign0010  https://insights.blackcoffer.com/rise-of-cyber...
# 10  blackassign0011  https://insights.blackcoffer.com/rise-of-inter...
# 11  blackassign0012  https://insights.blackcoffer.com/rise-of-telem...
# 12  blackassign0013  https://insights.blackcoffer.com/rise-of-e-hea...
# 13  blackassign0014  https://insights.blackcoffer.com/rise-of-e-hea...
# 14  blackassign0015  https://insights.blackcoffer.com/rise-of-telem...
# 15  blackassign0016  https://insights.blackcoffer.com/rise-of-telem...
# 16  blackassign0017  https://insights.blackcoffer.com/rise-of-chatb...
# 17  blackassign0018  https://insights.blackcoffer.com/rise-of-e-hea...
# 18  blackassign0019  https://insights.blackcoffer.com/how-does-mark...
# 19  blackassign0020  https://insights.blackcoffer.com/how-advertise...
# 20  blackassign0021  https://insights.blackcoffer.com/negative-effe...
# 21  blackassign0022  https://insights.blackcoffer.com/how-advertise...
# 22  blackassign0023  https://insights.blackcoffer.com/rising-it-cit...
# 23  blackassign0024  https://insights.blackcoffer.com/rise-of-ott-p...
# 24  blackassign0025  https://insights.blackcoffer.com/rise-of-elect...
# 25  blackassign0026  https://insights.blackcoffer.com/rise-of-elect...
# 26  blackassign0027  https://insights.blackcoffer.com/oil-prices-by...
# 27  blackassign0028  https://insights.blackcoffer.com/an-outlook-of...
# 28  blackassign0029  https://insights.blackcoffer.com/ai-in-healthc...
# 29  blackassign0030  https://insights.blackcoffer.com/what-if-the-c...
# 30  blackassign0031  https://insights.blackcoffer.com/what-jobs-wil...
# 31  blackassign0032  https://insights.blackcoffer.com/will-machine-...
# 32  blackassign0033  https://insights.blackcoffer.com/will-ai-repla...
# 33  blackassign0034  https://insights.blackcoffer.com/man-and-machi...
# 34  blackassign0035  https://insights.blackcoffer.com/in-future-or-...
# 35  blackassign0037  https://insights.blackcoffer.com/how-machine-l...
# 36  blackassign0038  https://insights.blackcoffer.com/deep-learning...
# 37  blackassign0039  https://insights.blackcoffer.com/how-to-protec...
# 38  blackassign0040  https://insights.blackcoffer.com/how-machines-...
# 39  blackassign0041  https://insights.blackcoffer.com/ai-human-robo...
# 40  blackassign0042  https://insights.blackcoffer.com/how-ai-will-c...
# 41  blackassign0043  https://insights.blackcoffer.com/future-of-wor...
# 42  blackassign0044  https://insights.blackcoffer.com/ai-tool-alexa...
# 43  blackassign0045  https://insights.blackcoffer.com/ai-healthcare...
# 44  blackassign0046  https://insights.blackcoffer.com/all-you-need-...
# 45  blackassign0047  https://insights.blackcoffer.com/evolution-of-...
# 46  blackassign0048  https://insights.blackcoffer.com/how-data-anal...
# 47  blackassign0050  https://insights.blackcoffer.com/environmental...
# 48  blackassign0051  https://insights.blackcoffer.com/how-data-anal...
# 49  blackassign0052  https://insights.blackcoffer.com/difference-be...
#
#     POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0                8               1        0.777778            0.583195
# 1               63              31        0.340426            0.429174
# 2               40              24        0.250000            0.431038
# 3               41              75       -0.293103            0.406442
# 4               23               8        0.483871            0.520523
# 5               90              27        0.538462            0.568148
# 6               24              44       -0.294118            0.462340
# 7               32               9        0.560976            0.444905
# 8               44              50       -0.063830            0.422792
# 9               62              68       -0.046154            0.504068
# 10              65              19        0.547619            0.397575
# 11              89              24        0.575221            0.437280
# 12              41              13        0.518519            0.615704
# 13              25              27       -0.038462            0.459666
# 14              43              27        0.228571            0.383727
# 15              43              27        0.228571            0.383727
# 16              49              12        0.606557            0.463518
# 17              43              10        0.622641            0.306089
# 18              70               6        0.842105            0.511676
# 19               9               0        1.000000            0.458420
# 20              29              47       -0.236842            0.565485
# 21              15              10        0.200000            0.516481
# 22              44              15        0.491525            0.404868
# 23              25               3        0.785714            0.560079
# 24              23              11        0.352941            0.432560
# 25              29              14        0.348837            0.426742
# 26              44              26        0.257143            0.452580
# 27              41              26        0.223881            0.426093
# 28              81              34        0.408696            0.463364
# 29              71              38        0.302752            0.433596
# 30              73              38        0.315315            0.486335
# 31              80              27        0.495327            0.496724
# 32              69              26        0.452632            0.510968
# 33              56              24        0.400000            0.452879
# 34              29              12        0.414634            0.423039
# 35              44              13        0.543860            0.574031
# 36              80              41        0.322314            0.530576
# 37              58              64       -0.049180            0.465973
# 38              47              22        0.362319            0.423288
# 39              42              29        0.183099            0.373062
# 40              72              24        0.500000            0.390488
# 41              75              22        0.546392            0.465690
# 42              28               0        1.000000            0.531168
# 43             104              39        0.454545            0.502121
# 44              27               0        1.000000            0.420735
# 45              15               6        0.428571            0.343422
# 46               2               3       -0.200000            0.361730
# 47              35              70       -0.333333            0.394056
# 48              21              15        0.166667            0.410028
# 49              72              38        0.309091            0.475039
#
#     AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 
#
#     SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0            1.567039                  4         4.558659
# 1            1.839917                  6         5.390852
# 2            2.102326                 13         6.104186
# 3            1.993415                  5         5.925682
# 4            1.804631                  6         5.520984
# 5            1.984383                  6         5.912763
# 6            1.756098                  1         5.204666
# 7            2.139715                  3         6.291074
# 8            2.119324                  3         6.248152
# 9            1.764151                  8         5.259119
# 10           1.943732                  3         5.763533
# 11           1.837999                  2         5.556879
# 12           1.811075                  3         5.436482
# 13           1.721357                  3         5.253896
# 14           1.770650                  7         5.449880
# 15           1.770650                  7         5.449880
# 16           1.793722                  5         5.430493
# 17           1.794470                  1         5.468203
# 18           1.712888                  5         5.191600
# 19           1.591241                  1         4.799270
# 20           1.865255                  6         5.498556
# 21           1.704327                  6         5.009615
# 22           1.663082                  7         4.966308
# 23           1.757895                  1         5.228070
# 24           1.558796                  6         4.679210
# 25           1.722531                  2         5.180910
# 26           1.524265                 27         4.563971
# 27           1.673094                 10         5.222612
# 28           1.860619                  1         5.607854
# 29           1.580289                  7         4.731220
# 30           1.806864                  3         5.339151
# 31           1.599381                 18         4.768421
# 32           1.642898                 18         4.952082
# 33           1.619906                 21         4.876176
# 34           1.648248                  7         5.044474
# 35           1.506812                  2         4.677112
# 36           1.650113                 11         4.828894
# 37           1.659520                  1         4.883614
# 38           1.791980                 10         5.392648
# 39           1.643825                  6         4.892430
# 40           1.582196                 32         4.745401
# 41           1.672131                 11         4.997478
# 42           1.788650                  0         5.432485
# 43           1.556153                 16         4.655024
# 44           1.707733                  0         5.052425
# 45           1.854342                  1         5.414566
# 46           1.779570                  2         5.344086
# 47           1.652080                  2         5.065997
# 48           1.650619                  5         4.976616
# 49           1.610450                 10         4.770823

# %%
print(output_df.tail(50))
# Out:
#              URL_ID                                                URL  \
# 48  blackassign0051  https://insights.blackcoffer.com/how-data-anal...
# 49  blackassign0052  https://insights.blackcoffer.com/difference-be...
# 50  blackassign0053  https://insights.blackcoffer.com/how-python-be...
# 51  blackassign0054  https://insights.blackcoffer.com/how-google-fi...
# 52  blackassign0055  https://insights.blackcoffer.com/what-is-the-f...
# 53  blackassign0056  https://insights.blackcoffer.com/impact-of-ai-...
# 54  blackassign0057  https://insights.blackcoffer.com/telemedicine-...
# 55  blackassign0058  https://insights.blackcoffer.com/how-we-foreca...
# 56  blackassign0059  https://insights.blackcoffer.com/can-robots-ta...
# 57  blackassign0060  https://insights.blackcoffer.com/embedding-car...
# 58  blackassign0061  https://insights.blackcoffer.com/management-ch...
# 59  blackassign0062  https://insights.blackcoffer.com/are-we-any-cl...
# 60  blackassign0063  https://insights.blackcoffer.com/will-technolo...
# 61  blackassign0064  https://insights.blackcoffer.com/will-we-ever-...
# 62  blackassign0065  https://insights.blackcoffer.com/will-we-ever-...
# 63  blackassign0066  https://insights.blackcoffer.com/what-is-the-c...
# 64  blackassign0067  https://insights.blackcoffer.com/why-does-your...
# 65  blackassign0068  https://insights.blackcoffer.com/how-you-lead-...
# 66  blackassign0069  https://insights.blackcoffer.com/can-you-be-gr...
# 67  blackassign0070  https://insights.blackcoffer.com/how-does-arti...
# 68  blackassign0071  https://insights.blackcoffer.com/how-to-overco...
# 69  blackassign0072  https://insights.blackcoffer.com/is-perfection...
# 70  blackassign0073  https://insights.blackcoffer.com/global-financ...
# 71  blackassign0074  https://insights.blackcoffer.com/gender-divers...
# 72  blackassign0075  https://insights.blackcoffer.com/how-to-overco...
# 73  blackassign0076  https://insights.blackcoffer.com/how-small-bus...
# 74  blackassign0077  https://insights.blackcoffer.com/impacts-of-co...
# 75  blackassign0078  https://insights.blackcoffer.com/impacts-of-co...
# 76  blackassign0079  https://insights.blackcoffer.com/impact-of-cov...
# 77  blackassign0080  https://insights.blackcoffer.com/impact-of-cov...
# 78  blackassign0081  https://insights.blackcoffer.com/changing-land...
# 79  blackassign0082  https://insights.blackcoffer.com/online-gaming...
# 80  blackassign0083  https://insights.blackcoffer.com/human-rights-...
# 81  blackassign0084  https://insights.blackcoffer.com/how-voice-sea...
# 82  blackassign0085  https://insights.blackcoffer.com/how-the-covid...
# 83  blackassign0086  https://insights.blackcoffer.com/how-to-increa...
# 84  blackassign0087  https://insights.blackcoffer.com/impacts-of-co...
# 85  blackassign0088  https://insights.blackcoffer.com/coronavirus-i...
# 86  blackassign0089  https://insights.blackcoffer.com/coronavirus-i...
# 87  blackassign0090  https://insights.blackcoffer.com/lessons-from-...
# 88  blackassign0091  https://insights.blackcoffer.com/estimating-th...
# 89  blackassign0092  https://insights.blackcoffer.com/estimating-th...
# 90  blackassign0093  https://insights.blackcoffer.com/travel-and-to...
# 91  blackassign0094  https://insights.blackcoffer.com/gaming-disord...
# 92  blackassign0095  https://insights.blackcoffer.com/what-is-the-r...
# 93  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 94  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 95  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 96  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 97  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
#     POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 48              21              15        0.166667            0.410028
# 49              72              38        0.309091            0.475039
# 50              53               3        0.892857            0.502752
# 51               9               1        0.800000            0.436289
# 52              27               8        0.542857            0.467353
# 53              14               8        0.272727            0.395499
# 54              20               9        0.379310            0.509545
# 55               6               0        1.000000            0.273859
# 56              27              37       -0.156250            0.481360
# 57              11               2        0.692308            0.456429
# 58              40              11        0.568627            0.399706
# 59               2               7       -0.555555            0.508918
# 60               9              25       -0.470588            0.615561
# 61              33              49       -0.195122            0.404066
# 62              58              23        0.432099            0.500299
# 63              48              26        0.297297            0.395279
# 64              26               7        0.575758            0.483674
# 65              53               7        0.766667            0.433015
# 66              38               6        0.727273            0.511039
# 67              50              16        0.515152            0.458634
# 68              35              74       -0.357798            0.575511
# 69              76              23        0.535354            0.637500
# 70              23              35       -0.206897            0.462848
# 71              30              23        0.132075            0.354553
# 72              35              78       -0.380531            0.558084
# 73              26              12        0.368421            0.476031
# 74               9               6        0.200000            0.378154
# 75              27              18        0.200000            0.389576
# 76              29              33       -0.064516            0.423638
